# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import numpy as np

# %%
# Out:
# Index(['Unnamed: 0', 'school.id', 'school.name_x', 'school.region',
#        'school.region.name', 'school.province', 'school.cityhall',
#        'school.division', 'school.citymuni', 'school.district',
#        'school.legdistrict', 'school.type', 'school.abbrev',
#        'school.previousname', 'school.mother.id', 'school.address',
#        'school.established', 'school.classification', 'school.classification2',
#        'school.curricularclass', 'school.organization', 'school.cityincome',
#        'school.cityclass', 'school.urban', 'school.name_y',
#        'school.enrollment', 'school.offering', 'school.mooe', 'School ID',
#        'rooms.standard.academic', 'rooms.standard.unused',
#        'rooms.nonstandard.academic', 'rooms.nonstandard.unused',
#        'teachers.instructor', 'teachers.mobile', 'teachers.regular',
#        'teachers.sped'],
#       dtype='object')

# %%
# Out:
# <ipython-input-3-2644bf048a96>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["teachersX"]= data["school.classification"].apply(lambda x: 4000 if x == "Elementary" else 8000)
# <ipython-input-3-2644bf048a96>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["roomsX"]= data["school.classification"].apply(lambda x: 3000 if x == "Elementary" else 6000)
# <ipython-input-3-2644bf048a96>:15: SettingWithCopyWarning:
# ...

# %%
# Out:
# <ipython-input-4-e4428f1544f8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["boncodin"]= boncodin
# <ipython-input-4-e4428f1544f8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["mooe-boncodin"] = data["school.mooe"]-boncodin
#        school.id school.classification  rooms  teachers  school.enrollment  \
# 0         101746            Elementary   15.0      21.0              781.0
# 1         102193            Elementary   16.0      18.0              465.0
# ...

# %%
# Out:
# 44025

# %%
# Out:
# 42342

# %%
# Out:
# 3.82282793867121

# %%
# Out:
#        school.id school.classification  rooms  teachers  school.enrollment  \
# 8695      108221            Elementary    9.0      95.0              646.0
# 42311     304015             Secondary   13.0      52.0              620.0
# 42839     304599             Secondary    7.0      69.0              261.0
# 36257     136785            Elementary   35.0     232.0             4017.0
# 5556      105919            Elementary    6.0      45.0              282.0
# ...          ...                   ...    ...       ...                ...
# 38226     301192             Secondary   54.0     195.0             6907.0
# 40311     303128             Secondary   57.0     213.0             5028.0
# 43796     305412             Secondary   71.0     192.0             5846.0
# 43974     305422             Secondary   63.0      96.0             2678.0
# 43954     305470             Secondary   65.0     209.0             6867.0
#
# ...

# %%
# Out:
# 'Correlation is: 0.9877355195250721'

# %%
# Out:
# 'Correlation is: 0.9930942489581726'

# %%
# Out:
# 'Correlation is: 0.9911436494110304'

# %%
len(data)
# Out:
# 44025

# %%
len(data)-len(data_cleaned)
# Out:
# 1683

# %%
len(data)-len(data_outliers_removed)
# Out:
# 6539

# %%
len(data)-len(data_outliers_removed_1)
# Out:
# 8879

# %%
8879/44025 * 100
# Out:
# 20.16808631459398

# %%
# Out:
# <ipython-input-22-539228b0b2d4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned["diff"] = (data_cleaned["school.mooe"]-data_cleaned["boncodin"])

# %%
data_cleaned["diff"].min() # Kulang (in Php)
# Out:
# -224200.0

# %%
data_cleaned["diff"].max() # Sobra (in Php)
# Out:
# 6316200.0

# %%
data_cleaned.merge(df2,on="school.id")[["school.cityclass","diff","school.cityincome","school.region.name"]].dropna().sort_values(by="diff")
# Out:
#             school.cityclass       diff  \
# 8569          Component City  -224200.0
# 35838  Highly Urbanized City  -121400.0
# 8387          Component City  -108800.0
# 39539  Highly Urbanized City   -72800.0
# 10024         Component City   -65000.0
# ...                      ...        ...
# 41036         Component City  3173400.0
# 39431  Highly Urbanized City  4155800.0
# 42133  Highly Urbanized City  4358600.0
# 42292  Highly Urbanized City  4764800.0
# 42274  Highly Urbanized City  6316200.0
#
#                            school.cityincome       school.region.name
# 8569                         P 400 M or more               CALABARZON
# 35838                        P 400 M or more  National Capital Region
# 8387   P 160 M or more but less than P 240 M               CALABARZON
# 39539                        P 400 M or more          Central Visayas
# 10024                        P 400 M or more               CALABARZON
# ...

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'school.id', 'school.name_x', 'school.region',
#        'school.region.name', 'school.province', 'school.cityhall',
#        'school.division', 'school.citymuni', 'school.district',
#        'school.legdistrict', 'school.type', 'school.abbrev',
#        'school.previousname', 'school.mother.id', 'school.address',
#        'school.established', 'school.classification', 'school.classification2',
#        'school.curricularclass', 'school.organization', 'school.cityincome',
#        'school.cityclass', 'school.urban', 'school.name_y',
#        'school.enrollment', 'school.offering', 'school.mooe', 'School ID',
#        'rooms.standard.academic', 'rooms.standard.unused',
#        'rooms.nonstandard.academic', 'rooms.nonstandard.unused',
#        'teachers.instructor', 'teachers.mobile', 'teachers.regular',
#        'teachers.sped', 'rooms', 'teachers'],
#       dtype='object')

# %%
data_outliers_removed_1
# Out:
#        school.id school.classification  rooms  teachers  school.enrollment  \
# 0         101746            Elementary   15.0      21.0              781.0
# 1         102193            Elementary   16.0      18.0              465.0
# 2         101283            Elementary    7.0       7.0              175.0
# 3         100216            Elementary    6.0       7.0              179.0
# 4         100043            Elementary    9.0       9.0              271.0
# ...          ...                   ...    ...       ...                ...
# 43761     305254             Secondary    4.0       9.0              235.0
# 43762     305256             Secondary    3.0       7.0               67.0
# 43769     305186             Secondary    4.0       8.0              205.0
# 43774     305227             Secondary    4.0       4.0              129.0
# 43804     319711             Secondary    7.0       0.0              344.0
#
# ...

# %%
df =data_cleaned
Q1 = df['school.mooe'].quantile(0.25)
Q3 = df['school.mooe'].quantile(0.75)
IQR = Q3 - Q1

df = (df[(df['school.mooe'] < Q1 - 1.5*IQR) | (df['school.mooe'] > Q3 + 1.5*IQR)])

# %%
data_cleaned.merge(df2,on="school.id")[["school.cityclass","diff","school.cityincome","school.region.name"]].dropna().sort_values(by="diff").groupby(["school.region.name"]).count().sort_values(by="school.cityincome")
# Out:
#                                   school.cityclass  diff  school.cityincome
# school.region.name
# Cordillera Administrative Region                54    54                 54
# Cagayan Valley                                 137   137                137
# MIMAROPA                                       151   151                151
# Soccsksargen                                   275   275                275
# CARAGA                                         344   344                344
# Bicol Region                                   376   376                376
# Ilocos Region                                  383   383                383
# Zamboanga Peninsula                            441   441                441
# Eastern Visayas                                521   521                521
# Davao Region                                   538   538                538
# Central Visayas                                592   592                592
# ...

# %%
# data_cleaned.merge(df2,on="school.id",how="left")[["school.name","school.mooe","boncodin","diff"]]

df_new
# Out:
#                school.mooe_x      boncodin         diff
# school.region
# CAR             2.854960e+08  2.508108e+08   34685200.0
# CARAGA          4.401100e+08  3.827078e+08   57402200.0
# NCR             1.177301e+09  9.612344e+08  216066600.0
# Region I        7.674280e+08  6.699710e+08   97457000.0
# Region II       5.381600e+08  4.675750e+08   70585000.0
# Region III      1.333392e+09  1.127482e+09  205910200.0
# Region IV-A     1.484045e+09  1.254797e+09  229248400.0
# Region IV-B     5.041510e+08  4.375842e+08   66566800.0
# Region IX       5.877440e+08  5.166402e+08   71103800.0
# Region V        1.022667e+09  8.930052e+08  129661800.0
# Region VI       1.156666e+09  1.013077e+09  143588600.0
# Region VII      9.865150e+08  8.459674e+08  140547600.0
# Region VIII     8.340230e+08  7.247560e+08  109267000.0
# Region X        6.299590e+08  5.456994e+08   84259600.0
# Region XI       6.332270e+08  5.560340e+08   77193000.0
# ...

# %%
plt.show()

# %%
df_school = df_plot
df_school["diff"] = df_school["diff"].abs()
df_school[df_school.sort_values(by="diff")["diff"] == 0]
# Out:
# <ipython-input-50-24e8536e9312>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_school[df_school.sort_values(by="diff")["diff"] == 0]
#                 school.name_x school.region  school.mooe_x  boncodin  diff
# 1103                  Kiat ES      Region I        61000.0   61000.0   0.0
# 1184              Licungan ES      Region I        74000.0   74000.0   0.0
# 1403            Matallucod PS      Region I        51000.0   51000.0   0.0
# 4356   Sto. Domingo ES - Main     Region II       116000.0  116000.0   0.0
# 5490          Don Dalmacio PS    Region III        51000.0   51000.0   0.0
# ...                       ...           ...            ...       ...   ...
# 35525                Pacak PS           CAR        52000.0   52000.0   0.0
# 35727          San Mariano PS           CAR        57000.0   57000.0   0.0
# 35805                Tabag PS           CAR        64000.0   64000.0   0.0
# ...

# %%
df_new["region"]=df_new.index
labels = df_new["region"]
mooe = df_new["school.mooe_x"]
boncodin = df_new["boncodin"]
width = 0.35       # the width of the bars: can also be len(x) sequence
x = np.arange(len(labels))  # the label locations
fig, ax = plt.subplots()

fig.set_figheight(10)
fig.set_figwidth(20)

rects1 = ax.bar(x - width/2, mooe, width, label='Actual MOOE')
rects2 = ax.bar(x + width/2, boncodin, width, label='Boncodin MOOE')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Amount in Php 1,000,000,000',fontsize=16)
ax.set_xlabel('Region',fontsize=16)
ax.set_title('Difference of Actual MOOE and Boncodin MOOE per Region',fontsize=24)
ax.legend()




plt.show()
df_new.index
# Out:
# Index(['CAR', 'CARAGA', 'NCR', 'Region I', 'Region II', 'Region III',
#        'Region IV-A', 'Region IV-B', 'Region IX', 'Region V', 'Region VI',
#        'Region VII', 'Region VIII', 'Region X', 'Region XI', 'Region XII'],
#       dtype='object', name='school.region')

# %%
88/43242*100
# Only 0.20% or 88 schools with the same MOOE and Boncodin MOOE


df_new
# Out:
#                school.mooe_x      boncodin         diff       region
# school.region
# CAR             2.854960e+08  2.508108e+08   34685200.0          CAR
# CARAGA          4.401100e+08  3.827078e+08   57402200.0       CARAGA
# NCR             1.177301e+09  9.612344e+08  216066600.0          NCR
# Region I        7.674280e+08  6.699710e+08   97457000.0     Region I
# Region II       5.381600e+08  4.675750e+08   70585000.0    Region II
# Region III      1.333392e+09  1.127482e+09  205910200.0   Region III
# Region IV-A     1.484045e+09  1.254797e+09  229248400.0  Region IV-A
# Region IV-B     5.041510e+08  4.375842e+08   66566800.0  Region IV-B
# Region IX       5.877440e+08  5.166402e+08   71103800.0    Region IX
# Region V        1.022667e+09  8.930052e+08  129661800.0     Region V
# Region VI       1.156666e+09  1.013077e+09  143588600.0    Region VI
# Region VII      9.865150e+08  8.459674e+08  140547600.0   Region VII
# ...

# %%
# Out:
#                                  school.name_x school.region  school.mooe_x  \
# 43954                Pedro E. Diaz High School           NCR     11205000.0
# 43974  Rizal Exp. Sta. And Pilot SCI (RESPSCI)           NCR      7062000.0
# 43796             Benigno "Ninoy" S. Aquino HS           NCR      8739000.0
# 40311               Abellana NHS (Day & NIght)    Region VII      8293000.0
# 38226            Gen. Mariano Alvarez Tech. HS   Region IV-A      8036000.0
# 42404       Digos City NHS (Davao Del Sur NHS)     Region XI      9813000.0
# 37507                        Capas High School    Region III      6232000.0
# 37503           Candelaria School of Fisheries    Region III      3723000.0
# 37453                    Benigno S. Aquino NHS    Region III      7424000.0
# 43863             Jose Fabella Memorial School           NCR      3628000.0
#
#         boncodin       diff
# 43954  4888800.0  6316200.0
# 43974  2297200.0  4764800.0
# 43796  4380400.0  4358600.0
# ...
